# %% [markdown]
# # Gen_PDB_ROTAMERS

# %% [markdown]
# 导入所需要的库

# %%
import os
import argparse
import re
import numpy as np
import shutil
from rdkit.Chem import Lipinski
from Bio.PDB import PDBParser, PDBIO, Superimposer
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem.rdForceFieldHelpers import UFFGetMoleculeForceField
import random

# %% [markdown]
# 读入SMILES文件及其他参数

# %%
'''
以下参数在脚本实际运行中为argparse参数,此处为了便于调试将其内置
-i: SMILES文件, 需要和参数化时使用的SMILES保持一致
-n: NCAA三字母缩写, 需要和参数化时使用的NCAA名保持一致
-m: 参考文件, 用于进行原子指认, 为参数化时得到的Rosetta临时文件
-d: RMSD阈值, 用于判断是否需要进行能量最小化, 默认值为0.1, 在不进行任何认为设置时会根据氨基酸chi角数量自动调整该阈值大小, 若人为干预则将不会进行自动调整, 而是采用用户输入的值
-c: cut_off值，默认根据chi角数量自动调整该值大小，若人为干预则将不会进行自动调整, 而是采用用户输入的值
'''

args_input='input.smiles'
args_names=['OAS']
args_params='OAS_temps.params'
args_rmsd_threshold=0.1
args_cut_off=10000

# %% [markdown]
# SMARTS反应定义

# %%
# 定义乙酰化和甲氨基化的SMARTS模式
acetylation_smarts = '[N:1][C:2][C:3](=[O:4])>>[C:5][C:7](=[O:6])[N:1][C:2][C:3](=[O:4])'
amidation_smarts = '[C:1][C:2](=[O:3])[O:4]>>[C:1][C:2]([N:5][C:6])(=[O:3])'

# %% [markdown]
# 计算chi角数量并定义cut_off值

# %%
def count_rotatable_bonds(smiles_file,cut_off):
    with open(smiles_file, 'r') as file:
        smiles_list = [line.strip() for line in file.readlines()]

    results = []

    for smiles in smiles_list:
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            print(f"SMILES字符串 '{smiles}' 无法解析")
            continue

        #计算自由旋转角个数，由于其包含主链上的一个自由旋转角，因此chi角个数为自由旋转角个数-1
        #c_value表示初始构象数，v_value表示cut_off值，如果用户通过参数干预，则v_value将会被设置为用户输入的值
        num_rotatable_bonds = Lipinski.NumRotatableBonds(mol)
        if num_rotatable_bonds==2 and cut_off==10000:
            v_value=10
            c_value=10000
        elif num_rotatable_bonds==3 and cut_off==10000:
            v_value=30
            c_value=10000
        elif num_rotatable_bonds==4 and cut_off==10000:
            v_value=90
            c_value=10000
        elif num_rotatable_bonds==5 and cut_off==10000:
            v_value=270
            c_value=10000
        elif num_rotatable_bonds>=6 and cut_off==10000:
            v_value=810
            c_value=10000
        else:
            v_value=cut_off
            c_value=10000
        results.append((smiles, num_rotatable_bonds, c_value, v_value))

    return results

results = count_rotatable_bonds(args_input,args_cut_off)
for smiles, num_rotatable_bonds, c_value, v_value in results:
    print(f"SMILES: {smiles}  自由旋转键数目: {num_rotatable_bonds}  c_value: {c_value}  v_value: {v_value}")
    # 将c_value和v_value输出为全局变量
    globals()['c_value'] = c_value
    globals()['v_value'] = v_value
# Out:
# SMILES: N[C@H](C(O)=O)COC(C)=O  自由旋转键数目: 3  c_value: 10000  v_value: 1000

# %% [markdown]
# 生成初始构象库

# %%
#为NCAA进行封端，并输出标准化的SMILES字符串
def process_smiles(smiles):
    mol = Chem.MolFromSmiles(smiles)

    if mol is None:
        raise ValueError(f"Unable to parse SMILES: '{smiles}'")

    # 创建乙酰化和甲氨基化的反应
    rxn_acetylation = AllChem.ReactionFromSmarts(acetylation_smarts)
    rxn_amidation = AllChem.ReactionFromSmarts(amidation_smarts)

    # 应用甲氨基化反应
    products_amidation = rxn_amidation.RunReactants((mol,))
    if not products_amidation:
        raise ValueError("C-terminal amidation failed")

    product_amidation = products_amidation[0][0]

    # 应用乙酰化反应
    products_acetylation = rxn_acetylation.RunReactants((product_amidation,))
    if not products_acetylation:
        raise ValueError("N-terminal acetylation failed")

    product_acetylation = products_acetylation[0][0]

    # 获取乙酰化后的分子的 SMILES
    final_smiles = Chem.MolToSmiles(product_acetylation, canonical=False)
    return final_smiles

# 将SMILES字符串转换为PDB文件
def smiles_to_pdb(smiles_list, names_list, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    if len(names_list) < len(smiles_list):
        names_list.extend(['UAA'] * (len(smiles_list) - len(names_list)))
    elif len(names_list) > len(smiles_list):
        raise ValueError("The number of provided names exceeds the number of SMILES strings.")

    generated_files = []
    for i, (smiles, name) in enumerate(zip(smiles_list, names_list)):
        mol = Chem.MolFromSmiles(smiles)
        if mol is None:
            print(f"SMILES字符串 '{smiles}' 无法解析")
            continue
        mol = Chem.AddHs(mol)
        # 设置随机种子以确保每次生成的构象具有更大的差异性
        random_seed = random.randint(1, 1000000)
        params = AllChem.ETKDG()
        params.randomSeed = random_seed
        AllChem.EmbedMolecule(mol, params)
        
        # 使用UFF力场进行结构优化
        ff = UFFGetMoleculeForceField(mol)
        ff.Initialize()
        ff.Minimize()

        # 获取结构优化后的能量值
        energy = ff.CalcEnergy()

        # 生成PDB文件名
        pdb_filename = os.path.join(output_dir, f'{name}_{i+1}.pdb')
        
        # 写入PDB文件并添加能量和SMILES信息
        with open(pdb_filename, 'w') as pdb_file:
            pdb_file.write(f"REMARK SMILES: {smiles}\n")
            pdb_file.write(f"REMARK Energy after optimization: {energy:.2f} kcal/mol\n")
            pdb_file.write(Chem.rdmolfiles.MolToPDBBlock(mol))
        
        generated_files.append(pdb_filename)
        print(f"生成 {pdb_filename}")
        

    return generated_files

# 调试用，便于为函数传参
input_file=args_input
names_list=args_names
combined_file = 'combined_pdb_files.pdb'
print(input_file)
print(names_list)

# 生成封端后的SMILES字符串
def gen_smiles(input_file, names_list):

    with open(input_file, 'r') as f:
        smiles_list = [line.strip() for line in f.readlines()]

    if len(names_list) != len(smiles_list):
        raise ValueError("The number of provided names does not match the number of SMILES strings.")

    processed_smiles_list = []
    for smiles in smiles_list:
        try:

            processed_smiles = process_smiles(smiles)
            processed_smiles_list.append(processed_smiles)
        except ValueError as e:
            print(e)
            continue
    return processed_smiles_list

# 将smiles转化为pdb
def gen_conformers(processed_smiles_list, names_list):

    output_dir = 'pdb_files'
    generated_files = smiles_to_pdb(processed_smiles_list, names_list, output_dir)

# 将每一轮循环中生成的pdb文件追加到combined_pdb_files.pdb中
def append_pdb_to_combined_file(pdb_file, combined_file):
    with open(pdb_file, 'r') as f_pdb:
        pdb_content = f_pdb.read()
    
    with open(combined_file, 'a') as f_combined:
        f_combined.write(pdb_content)

if os.path.exists(combined_file):
    os.remove(combined_file)

# 生成封端后的SMILES
processed_smiles_list = gen_smiles(input_file, names_list)

# 循环调用gen_conformers函数，直到生成c_value个构象(10000个)
for i in range(c_value):
    print(f"Running iteration {i + 1}...")
    gen_conformers(processed_smiles_list, names_list)

    # 将pdb_files文件夹中的所有PDB文件内容追加到combined_pdb_files.pdb中
    for pdb_file in os.listdir('pdb_files'):
        if pdb_file.endswith('.pdb'):
            pdb_filepath = os.path.join('pdb_files', pdb_file)
            append_pdb_to_combined_file(pdb_filepath, combined_file)
    
    print(f"Iteration {i + 1} completed.")
# Out:
# input.smiles
# ['OAS']
# Running iteration 1...
# 生成 pdb_files/OAS_1.pdb
# Iteration 1 completed.
# Running iteration 2...
# 生成 pdb_files/OAS_1.pdb
# Iteration 2 completed.
# Running iteration 3...
# 生成 pdb_files/OAS_1.pdb
# Iteration 3 completed.
# Running iteration 4...
# 生成 pdb_files/OAS_1.pdb
# Iteration 4 completed.
# Running iteration 5...
# 生成 pdb_files/OAS_1.pdb
# Iteration 5 completed.
# Running iteration 6...
# 生成 pdb_files/OAS_1.pdb
# Iteration 6 completed.
# Running iteration 7...
# [15:41:17] product atom-mapping number 5 not found in reactants.
# [15:41:17] product atom-mapping number 6 not found in reactants.
# [15:41:17] mapped atoms in the reactants were not mapped in the products.
#   unmapped numbers are: 4
# [15:41:17] product atom-mapping number 5 not found in reactants.
# [15:41:17] product atom-mapping number 7 not found in reactants.
# [15:41:17] product atom-mapping number 6 not found in reactants.
# 生成 pdb_files/OAS_1.pdb
# Iteration 7 completed.
# Running iteration 8...
# 生成 pdb_files/OAS_1.pdb
# Iteration 8 completed.
# Running iteration 9...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9 completed.
# Running iteration 10...
# 生成 pdb_files/OAS_1.pdb
# Iteration 10 completed.
# Running iteration 11...
# 生成 pdb_files/OAS_1.pdb
# Iteration 11 completed.
# Running iteration 12...
# 生成 pdb_files/OAS_1.pdb
# Iteration 12 completed.
# Running iteration 13...
# 生成 pdb_files/OAS_1.pdb
# Iteration 13 completed.
# Running iteration 14...
# 生成 pdb_files/OAS_1.pdb
# Iteration 14 completed.
# Running iteration 15...
# 生成 pdb_files/OAS_1.pdb
# Iteration 15 completed.
# Running iteration 16...
# 生成 pdb_files/OAS_1.pdb
# Iteration 16 completed.
# Running iteration 17...
# 生成 pdb_files/OAS_1.pdb
# Iteration 17 completed.
# Running iteration 18...
# 生成 pdb_files/OAS_1.pdb
# Iteration 18 completed.
# Running iteration 19...
# 生成 pdb_files/OAS_1.pdb
# Iteration 19 completed.
# Running iteration 20...
# 生成 pdb_files/OAS_1.pdb
# Iteration 20 completed.
# Running iteration 21...
# 生成 pdb_files/OAS_1.pdb
# Iteration 21 completed.
# Running iteration 22...
# 生成 pdb_files/OAS_1.pdb
# Iteration 22 completed.
# Running iteration 23...
# 生成 pdb_files/OAS_1.pdb
# Iteration 23 completed.
# Running iteration 24...

# 生成 pdb_files/OAS_1.pdb
# Iteration 9971 completed.
# Running iteration 9972...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9972 completed.
# Running iteration 9973...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9973 completed.
# Running iteration 9974...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9974 completed.
# Running iteration 9975...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9975 completed.
# Running iteration 9976...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9976 completed.
# Running iteration 9977...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9977 completed.
# Running iteration 9978...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9978 completed.
# Running iteration 9979...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9979 completed.
# Running iteration 9980...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9980 completed.
# Running iteration 9981...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9981 completed.
# Running iteration 9982...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9982 completed.
# Running iteration 9983...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9983 completed.
# Running iteration 9984...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9984 completed.
# Running iteration 9985...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9985 completed.
# Running iteration 9986...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9986 completed.
# Running iteration 9987...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9987 completed.
# Running iteration 9988...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9988 completed.
# Running iteration 9989...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9989 completed.
# Running iteration 9990...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9990 completed.
# Running iteration 9991...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9991 completed.
# Running iteration 9992...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9992 completed.
# Running iteration 9993...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9993 completed.
# Running iteration 9994...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9994 completed.
# Running iteration 9995...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9995 completed.
# Running iteration 9996...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9996 completed.
# Running iteration 9997...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9997 completed.
# Running iteration 9998...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9998 completed.
# Running iteration 9999...
# 生成 pdb_files/OAS_1.pdb
# Iteration 9999 completed.
# Running iteration 10000...
# 生成 pdb_files/OAS_1.pdb
# Iteration 10000 completed.

# %% [markdown]
# 按能量从小到大对combined_pdb_file.pdb进行排序，以保证低能量构象被优先存入PDB ROTAMERS库中

# %%
n_value = args_names[0]
combined_pdb_file = 'combined_pdb_files.pdb'  # 合并的PDB文件名
output_directory = 'split_pdb_files'  # 存放拆分后PDB文件的目录

# 根据combined_pdb_file中的能量注释行提取能量值
def extract_energy_from_pdb(pdb_content):
    lines = pdb_content.splitlines()
    energy = None
    for line in lines:
        if line.startswith("REMARK Energy after optimization:"):
            energy = float(re.search(r'\d+\.\d+', line).group())
            break
    if energy is None:
        raise ValueError("No energy information found in PDB content")
    return energy

# 对PDB文件中的原子编号进行重新排序
def process_pdb_file(filepath, n_value, output_filepath, energy_value):
    with open(filepath, 'r') as file:
        lines = file.readlines()

    # 添加能量值注释行
    energy_line = f"REMARK Energy after optimization: {energy_value:.2f}\n"

    # 过滤掉不是以 "HETATM" 或 "ATOM  " 开头的行
    lines = [line for line in lines if line.startswith("HETATM") or line.startswith("ATOM  ")]

    # 字典存储需要重新排序的行
    line_dict = {"C2": None, "O1": None, "C1": None, "H1": None, "H2": None, "H3": None,
                 "N2": None, "C5": None, "H6": None, "H7": None, "H8": None, "H9": None,
                 "N1": None, "C3": None, "C4": None, "O2": None, "H4": None, "H5": None}
    other_lines = []

    for line in lines:
        atom_name = line[12:16].strip()
        if atom_name in line_dict:
            line_dict[atom_name] = line
        else:
            other_lines.append(line)

    # 按指定顺序重新排列行
    reordered_lines = []
    for key in ["C2", "O1", "C1", "H1", "H2", "H3", "N2", "C5", "H6", "H7", "H8", "H9", "N1", "C3", "C4", "O2"]:
        if line_dict[key] is not None:
            reordered_lines.append(line_dict[key])

    reordered_lines.extend(other_lines)

    if line_dict["H4"] is not None:
        reordered_lines.append(line_dict["H4"])

    if line_dict["H5"] is not None:
        reordered_lines.append(line_dict["H5"])

    # 修改残基名
    for i in range(len(reordered_lines)):
        if i < 6:
            reordered_lines[i] = reordered_lines[i][:17] + "ACE" + reordered_lines[i][20:]
        elif i < 12:
            reordered_lines[i] = reordered_lines[i][:17] + "NME" + reordered_lines[i][20:]
        else:
            reordered_lines[i] = reordered_lines[i][:17] + n_value + reordered_lines[i][20:]

    # 在开头添加能量值注释行
    reordered_lines.insert(0, energy_line)

    # 添加 "END" 行
    reordered_lines.append("END\n")

    # 写回新文件
    with open(output_filepath, 'w') as file:
        file.writelines(reordered_lines)

# 拆分合并的PDB文件并按能量值由小到大排序
def split_combined_pdb(combined_pdb_file, output_dir, n_value):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    pdb_files = []
    energies = {}

    with open(combined_pdb_file, 'r') as f:
        content = f.read().strip().split('END\n')

    for idx, pdb_block in enumerate(content):
        if pdb_block.strip():
            pdb_content = pdb_block.strip() + '\nEND'
            energy = extract_energy_from_pdb(pdb_content)

            # 创建PDB文件名，使用能量值命名
            pdb_filename = os.path.join(output_dir, f'conformer_{energy:.2f}.pdb')

            with open(pdb_filename, 'w') as pdb_out:
                pdb_out.write(pdb_content)

            pdb_files.append((pdb_filename, energy))
            energies[pdb_filename] = energy

            # 对每个拆分的PDB文件的原子编号进行重新排序
            output_filepath = f"{pdb_filename}_processed.pdb"
            process_pdb_file(pdb_filename, n_value, output_filepath, energy)
            print(f"已处理PDB文件: {output_filepath}")

    # 按能量排序生成的PDB文件
    sorted_files = sorted(pdb_files, key=lambda x: x[1])

    # 创建新的合并PDB文件并按能量顺序写入排序后的pdb
    combined_sorted_file = 'combined_sorted_pdb_files.pdb'
    with open(combined_sorted_file, 'w') as f_combined:
        for pdb_file, _ in sorted_files:
            with open(pdb_file + "_processed.pdb", 'r') as f_pdb:
                pdb_content = f_pdb.read()
                f_combined.write(pdb_content)

    return combined_sorted_file

try:
    sorted_combined_file = split_combined_pdb(combined_pdb_file, output_directory, n_value)
    print(f"已创建排序后的合并PDB文件: {sorted_combined_file}")

except Exception as e:
    print(f"错误: {e}")
# Out:
# 已处理PDB文件: split_pdb_files/conformer_20.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.02.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.02.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_32.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_34.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.41.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.72.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.79.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_51.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.86.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_26.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.50.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.36.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_27.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.96.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.06.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.12.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_27.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_47.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.35.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.06.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_31.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.02.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_36.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_30.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.27.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.57.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.79.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_26.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.30.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_26.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_31.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.18.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.78.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.02.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.49.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.57.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.96.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.72.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.07.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_32.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_35.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_26.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_27.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_27.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_35.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.86.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.18.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_30.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.41.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_32.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.86.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.72.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.12.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_29.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_38.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.49.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.36.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_32.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_37.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_39.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.12.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_46.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.41.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.78.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.35.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.06.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.27.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.57.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_29.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.06.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.30.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.49.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.12.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_29.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.50.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_26.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.05.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.57.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.79.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.50.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.35.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.90.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.93.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.18.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.96.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.37.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.06.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.67.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_24.49.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.78.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.30.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_29.36.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.70.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.96.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_28.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_35.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.44.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.43.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.23.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.58.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_35.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_25.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.00.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.35.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.41.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.30.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.12.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.24.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.27.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.30.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.31.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.80.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.79.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.07.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.84.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.48.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.87.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.69.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.17.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.49.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.39.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.21.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.36.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.86.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.51.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.81.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.25.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.36.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.76.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_27.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.59.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.26.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.94.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.16.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.10.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_20.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.47.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.89.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.71.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.77.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.72.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.68.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.46.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.66.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.65.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.14.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_23.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.86.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_32.60.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.18.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.82.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.98.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.01.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.22.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.38.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.04.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.61.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.79.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.87.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.74.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_12.34.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.88.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_29.35.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.11.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.27.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.95.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.27.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.50.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.63.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_47.62.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_31.03.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.64.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.45.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.32.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.07.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.97.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.33.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.29.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.52.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.20.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_21.19.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_18.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.56.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.73.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.09.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.28.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_41.13.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.83.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.96.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.85.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_16.92.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_22.91.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_19.87.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.54.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.75.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.53.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.40.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_13.42.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.15.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_15.99.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_14.55.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_17.08.pdb_processed.pdb
# 已处理PDB文件: split_pdb_files/conformer_34.39.pdb_processed.pdb
# 已创建排序后的合并PDB文件: combined_sorted_pdb_files.pdb

# %%
rmsd_threshold = args.rmsd_threshold
if rmsd_threshold==0.001 and v_value==10:
    rmsd_threshold = 0.80
elif rmsd_threshold==0.001 and v_value==30:
    rmsd_threshold = 0.60
elif rmsd_threshold==0.001 and v_value==90:
    rmsd_threshold = 0.40
elif rmsd_threshold==0.001 and v_value==270:
    rmsd_threshold = 0.20
elif rmsd_threshold==0.001 and v_value==810:
    rmsd_threshold = 0.10
print(rmsd_threshold)

# 定义主链原子名
backbone_atoms = {'C3', 'C4', 'O1', 'N1', 'O2'}

# 获取主链原子
def get_backbone_atoms(structure):

    return [atom for atom in structure.get_atoms() if atom.get_name() in backbone_atoms]

# 按主链对所有pdb进行align，并使用对齐后的pdb文件并覆盖原始PDB文件
def align_and_overwrite(ref_structure, pdb_file, parser):

    structure = parser.get_structure(pdb_file, pdb_file)
    
    # 获取主链原子
    ref_atoms = get_backbone_atoms(ref_structure)
    mobile_atoms = get_backbone_atoms(structure)
    
    # 使用 Superimposer 进行对齐
    super_imposer = Superimposer()
    super_imposer.set_atoms(ref_atoms, mobile_atoms)
    super_imposer.apply(structure.get_atoms())

    # 保存对齐后的结构到原始PDB文件中
    io = PDBIO()
    io.set_structure(structure)
    io.save(pdb_file)

# Kabsch算法计算最佳旋转矩阵
def kabsch_algorithm(P, Q):
    # 中心化
    P_centered = P - np.mean(P, axis=0)
    Q_centered = Q - np.mean(Q, axis=0)
    
    # 计算协方差矩阵
    H = np.dot(P_centered.T, Q_centered)
    
    # 计算SVD
    U, S, Vt = np.linalg.svd(H)
    
    # 计算旋转矩阵
    V = Vt.T
    d = np.sign(np.linalg.det(np.dot(V, U.T)))
    R = np.dot(V, np.dot(np.diag([1, 1, d]), U.T))
    
    return R

# 计算两个点集之间的RMSD
def calculate_rmsd(P, Q):

    P_centered = P - np.mean(P, axis=0)
    Q_centered = Q - np.mean(Q, axis=0)
    
    R = kabsch_algorithm(P_centered, Q_centered)
    P_rot = np.dot(P_centered, R)
    
    diff = P_rot - Q_centered
    rmsd = np.sqrt(np.mean(np.sum(diff**2, axis=1)))
    
    return rmsd

# 从PDB文件中提取排除指定原子外的坐标和名称
def get_coordinates(structure, atoms_to_exclude):

    atoms = []
    coords = []
    for atom in structure.get_atoms():
        if atom.get_name() not in atoms_to_exclude and 'H' not in atom.get_name():  # 排除主链，封端和所有氢原子
            atoms.append(atom.get_name())
            coords.append(atom.get_coord())
    
    return np.array(coords), atoms

# 计算两个构象之间的RMSD
def align_and_calculate_rmsd(ref_structure, temp_structure, original_pdb_file):
    # 指定在RMSD计算中要排除的主链，封端和所有氢原子
    atoms_to_exclude = {'C1', 'C2', 'C4', 'C5', 'O1', 'O2', 'N1', 'N2'}
    
    coords1, atom_names1 = get_coordinates(ref_structure, atoms_to_exclude)
    coords2, atom_names2 = get_coordinates(temp_structure, atoms_to_exclude)
    
    if coords1.shape != coords2.shape:
        raise ValueError("两个PDB文件的坐标数量不一致")
    
    rmsd_value = calculate_rmsd(coords1, coords2)
    
    return rmsd_value

# 遍历每一个构象，将其与最终构象库中的所有构象进行RMSD比对，当且仅当被遍历的构象与最终构象库中的所有构象的RMSD值均大于阈值时，将其写入最终的合并文件
def align_structures_and_check_rmsd(pdb_files, parser, aligned_combined_pdb_filename, rmsd_threshold):
    aligned_structures = []
    conformer_count = 0

    with open(aligned_combined_pdb_filename, 'w') as aligned_combined_pdb:
        ref_pdb_file = pdb_files[0]
        ref_structure = parser.get_structure('reference', ref_pdb_file)
        align_and_overwrite(ref_structure, ref_pdb_file, parser)
        aligned_structures.append(ref_structure)

        for pdb_file in pdb_files[1:]:
            if conformer_count >=v_value or conformer_count >= len(pdb_files):
                break

            align_and_overwrite(ref_structure, pdb_file, parser)
            temp_structure = parser.get_structure('temp_aligned', pdb_file)

            # 比较temp_structure与aligned_combined_pdb_files.pdb中所有结构的RMSD值
            should_keep = True
            for aligned_structure, aligned_pdb_file in zip(aligned_structures, pdb_files):
                rmsd = align_and_calculate_rmsd(aligned_structure, temp_structure, aligned_pdb_file)
                print(f"RMSD between {os.path.basename(pdb_file)} and {os.path.basename(aligned_pdb_file)}: {rmsd}")
                if rmsd < rmsd_threshold:
                    should_keep = False
                    break
            
            # 如果不存在RMSD小于阈值的结果，则将temp_structure写入最终的合并文件
            if should_keep:
                with open(pdb_file, 'r') as temp_file:
                    lines = temp_file.readlines()
                    for line in lines:
                        if line.startswith(('REMARK', 'ATOM', 'HETATM', 'END')):
                            aligned_combined_pdb.write(line)
                
                conformer_count += 1
                aligned_structures.append(temp_structure)

    # 输出实际生成的构象个数
    print(f"实际生成的构象个数为: {conformer_count}")

# 从combined_sorted_pdb_files.pdb文件中读取所有PDB结构并进行RMSD筛选
def screen_rmsd(rmsd_threshold):
    parser = PDBParser(QUIET=True)

    # 读取combined_pdb_files.pdb文件
    with open('combined_sorted_pdb_files.pdb', 'r') as f:
        content = f.read().strip().split('END\n')

    # 将每个PDB结构写入单独的文件
    pdb_files = []
    for i, pdb_content in enumerate(content):
        if pdb_content.strip():
            pdb_filename = f'pdb_{i}.pdb'
            with open(pdb_filename, 'w') as pdb_file:
                pdb_file.write(pdb_content + 'END\n')
            pdb_files.append(pdb_filename)

    # 创建一个新的文件来存储所有对齐后的PDB结构
    aligned_combined_pdb_filename = 'aligned_combined_pdb_files.pdb'

    align_structures_and_check_rmsd(pdb_files, parser, aligned_combined_pdb_filename, rmsd_threshold)

    # 删除中间生成的PDB文件
    for pdb_file in pdb_files:
        os.remove(pdb_file)

    print(f"已创建合并PDB文件: aligned_combined_pdb_files.pdb")

try:
    screen_rmsd(rmsd_threshold)

except Exception as e:
    print(f"错误: {e}")
# Out:
# 1.8
# RMSD between pdb_1.pdb and pdb_0.pdb: 0.17983554003210547
# RMSD between pdb_2.pdb and pdb_0.pdb: 0.17983554003210547
# RMSD between pdb_3.pdb and pdb_0.pdb: 0.25709062273838185
# RMSD between pdb_4.pdb and pdb_0.pdb: 0.06210736555629287
# RMSD between pdb_5.pdb and pdb_0.pdb: 0.05707898156198986
# RMSD between pdb_6.pdb and pdb_0.pdb: 0.21408144714537145
# RMSD between pdb_7.pdb and pdb_0.pdb: 0.07829706915694078
# RMSD between pdb_8.pdb and pdb_0.pdb: 0.09825986776426197
# RMSD between pdb_9.pdb and pdb_0.pdb: 0.1944415798097
# RMSD between pdb_10.pdb and pdb_0.pdb: 0.27922900689288804
# RMSD between pdb_11.pdb and pdb_0.pdb: 0.1986055337772643
# RMSD between pdb_12.pdb and pdb_0.pdb: 0.1986055337772643
# RMSD between pdb_13.pdb and pdb_0.pdb: 0.3206170066769032
# RMSD between pdb_14.pdb and pdb_0.pdb: 0.22939494327891363
# RMSD between pdb_15.pdb and pdb_0.pdb: 1.7477964409871318
# RMSD between pdb_16.pdb and pdb_0.pdb: 0.19461203247054895
# RMSD between pdb_17.pdb and pdb_0.pdb: 0.13465169563976687
# RMSD between pdb_18.pdb and pdb_0.pdb: 0.1494275970410241
# RMSD between pdb_820.pdb and pdb_1.pdb: 2.500652303932463
# RMSD between pdb_820.pdb and pdb_2.pdb: 2.5871976524928777
# RMSD between pdb_820.pdb and pdb_3.pdb: 1.206443084743685
# 实际生成的构象个数为: 5
# 已创建合并PDB文件: aligned_combined_pdb_files.pdb

# %%
# 定义split_pdb_directory文件夹
split_pdb_directory = 'split_pdbs'

# 从PDB文件中删除包含'ACE'或'NME'的行，并重新编写原子编号
def remove_ace_nme_lines(pdb_filename):

    lines = []
    current_residue_number = 1

    with open(pdb_filename, 'r') as f:
        for line in f:
            if 'ACE' in line or 'NME' in line:
                continue
            if line.startswith('ATOM'):
                # 重新编写原子编号
                line = f"{line[:6]}{current_residue_number:>4}{line[10:]}"
                current_residue_number += 1
            lines.append(line)

    # 将修改后的行写回原始PDB文件
    with open(pdb_filename, 'w') as f:
        f.write(''.join(lines))

# 将PDB文件拆分为单个构象
def split_pdb_file(input_pdb_file):

    output_directory = 'split_pdbs'
    os.makedirs(output_directory, exist_ok=True)

    conformation_index = 1
    pdb_content = []

    with open(input_pdb_file, 'r') as f:
        for line in f:
            if line.strip() == 'END':
                pdb_filename = os.path.join(output_directory, f'conformation_{conformation_index}.pdb')
                with open(pdb_filename, 'w') as pdb_file:
                    pdb_file.write('\n'.join(pdb_content) + '\nENDMDL\n')

                conformation_index += 1
                pdb_content = []
            else:
                pdb_content.append(line.strip())

    if pdb_content:
        pdb_filename = os.path.join(output_directory, f'conformation_{conformation_index}.pdb')
        with open(pdb_filename, 'w') as pdb_file:
            pdb_file.write('\n'.join(pdb_content) + '\nENDMDL\n')

# 读取XXX_temps.params文件并替换PDB文件中的[12:16]为非天然氨基酸名称
def process_all_pdb_files(directory, non_natural_aa_codes):

    for filename in os.listdir(directory):
        if filename.endswith('.pdb'):
            pdb_filepath = os.path.join(directory, filename)
            remove_ace_nme_lines(pdb_filepath)
            # 读取PDB文件并替换[12:16]为非天然氨基酸名称
            lines = []
            with open(pdb_filepath, 'r') as f:
                for idx, line in enumerate(f):
                    if line.strip() == 'ENDMDL':
                        lines.append(line)
                        continue
                    if idx < len(non_natural_aa_codes):
                        code = non_natural_aa_codes[idx]
                        line = line[:12] + code + line[16:]
                    lines.append(line)
            
            # 将修改后的行写回原始PDB文件
            with open(pdb_filepath, 'w') as f:
                f.write(''.join(lines))

            print(f"Processed: {filename}")

# 将split_pdb_directory中的所有PDB文件合并为单个输出文件
def combine_pdb_files(output_filename):

    with open(output_filename, 'w') as output_file:
        conformation_index = 1
        for filename in sorted(os.listdir(split_pdb_directory)):
            if filename.endswith('.pdb'):
                pdb_filepath = os.path.join(split_pdb_directory, filename)
                with open(pdb_filepath, 'r') as pdb_file:
                    output_file.write(f"MODEL     {conformation_index}\n")
                    for line in pdb_file:
                        output_file.write(line)
                    conformation_index += 1

# 删除split_pdb_directory
def remove_split_pdb_directory(directory):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            if os.path.isfile(file_path):
                os.remove(file_path)
            elif os.path.isdir(file_path):
                os.rmdir(file_path)
        except Exception as e:
            print(f"Failed to delete {file_path}. Reason: {e}")

    try:
        os.rmdir(directory)
    except Exception as e:
        print(f"Failed to delete {directory}. Reason: {e}")

# 调整索引号，将第二列（索引10:11）减去12，使其从1开始编号
def adjust_hetatm_records(pdb_filename):

    lines = []
    with open(pdb_filename, 'r') as f:
        for line in f:
            if line.startswith('HETATM'):
                original_number = int(line[9:11])
                modified_number = original_number - 12
                # Adjust right alignment
                if modified_number < 10:
                    line = f"{line[:9]} {modified_number}{line[11:]}"
                else:
                    line = f"{line[:9]}{modified_number}{line[11:]}"
            lines.append(line)

    with open(pdb_filename, 'w') as f:
        f.writelines(lines)

# 执行函数，调用以上modify功能，对pdb文件进行修改
def modify(non_natural_aa_abbreviation):

    params_filename = f"{non_natural_aa_abbreviation}_temps.params"

    # 读取XXX_temps.params文件中的非天然氨基酸原子编号
    non_natural_aa_codes = []
    with open(params_filename, 'r') as params_file:
        for line in params_file:
            if line.startswith('ATOM'):
                code = line.strip()[5:9]
                non_natural_aa_codes.append(code)

    # 拆分合并的PDB文件
    input_pdb_file = 'aligned_combined_pdb_files.pdb'
    split_pdb_file(input_pdb_file)

    # 处理拆分后的PDB文件
    process_all_pdb_files(split_pdb_directory, non_natural_aa_codes)

    # 合并处理后的PDB文件
    combined_pdb_filename = 'merged_combined_pdb_files.pdb'
    combine_pdb_files(combined_pdb_filename)

    # 调整原子索引号
    adjust_hetatm_records(combined_pdb_filename)

    # 删除split_pdb_directory
    remove_split_pdb_directory(split_pdb_directory)
    print(f"Combined PDB files into '{combined_pdb_filename}' and deleted '{split_pdb_directory}'.")

non_natural_aa_abbreviation = n_value

try:
    modify(non_natural_aa_abbreviation)
except Exception as e:
    print(f"Error: {e}")
# Out:
# Processed: conformation_8.pdb
# Processed: conformation_3.pdb
# Processed: conformation_7.pdb
# Processed: conformation_4.pdb
# Processed: conformation_9.pdb
# Processed: conformation_10.pdb
# Processed: conformation_1.pdb
# Processed: conformation_5.pdb
# Processed: conformation_6.pdb
# Processed: conformation_2.pdb
# Combined PDB files into 'merged_combined_pdb_files.pdb' and deleted 'split_pdbs'.

# %%
# 删除临时文件
def delete_files():
    files_to_delete = ['combined_pdb_files.pdb', 'combined_sorted_pdb_files.pdb', 'aligned_combined_pdb_files.pdb']
    
    for file in files_to_delete:
        try:
            os.remove(file)
            print(f"Successfully deleted {file}")
        except FileNotFoundError:
            print(f"File {file} not found")
        except PermissionError:
            print(f"Permission denied to delete {file}")
        except Exception as e:
            print(f"Error deleting {file}: {e}")

    if os.path.exists('pdb_files'):
        shutil.rmtree('pdb_files')
        print("Deleted 'pdb_files' directory")

    if os.path.exists('split_pdb_files'):
        shutil.rmtree('split_pdb_files')
        print("Deleted 'split_pdb_files' directory")

delete_files()
# Out:
# Successfully deleted combined_pdb_files.pdb
# Successfully deleted combined_sorted_pdb_files.pdb
# Successfully deleted aligned_combined_pdb_files.pdb
# Deleted 'pdb_files' directory
# Deleted 'split_pdb_files' directory
